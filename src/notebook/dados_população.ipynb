# %% [markdown]
# # Informação:
# * Dados obtidos do site https://sidra.ibge.gov.br/tabela/6579 em 07/09/2025
# * o IBGE não publicou a estimativa de 2007
# * Estimativas de 2022 e 2023 não foram divulgadas por conta da pandemia.

# %% [markdown]
# # Objetivo:
#   * Organizar por Codigo do municipio, e por ano.
#   * Os dados das colunas numéricas se referem a estimativa populacional do IBGE.

# %%
import pandas as pd
import io

# %% [markdown]
# # 📚 Extração dos Dados~

# %% [markdown]
# * Baixando o CSV hospedado no github
# * Lendo o arquivo

# %%
url = 'https://gist.githubusercontent.com/OliveiraGmo/d31a9cd887092193929189b1c912cc2a/raw/e3178dac89ad09ef04ce8761a8abb7c3e3ac8a84/dados_ibge.csv'

# %%
população_rmvp = pd.read_csv(url, sep=',')
população_rmvp.head(5)
# Out:
#     Cód.Município       Municipio   2006 Unnamed: 3   2008 Unnamed: 5   2009  \
# MU        3502507  Aparecida (SP)  36129    Pessoas  37405    Pessoas  37629
# MU        3503158     Arapeí (SP)   2857    Pessoas   2587    Pessoas   2582
# MU        3503505     Areias (SP)   3834    Pessoas   3684    Pessoas   3690
# MU        3504909    Bananal (SP)  10185    Pessoas  10727    Pessoas  10822
# MU        3508504   Caçapava (SP)  83574    Pessoas  84406    Pessoas  85181
#
#    Unnamed: 7   2011 Unnamed: 9  ...   2019 Unnamed: 25   2020 Unnamed: 27  \
# MU    Pessoas  35015    Pessoas  ...  36157     Pessoas  36185     Pessoas
# MU    Pessoas   2484    Pessoas  ...   2469     Pessoas   2460     Pessoas
# MU    Pessoas   3704    Pessoas  ...   3886     Pessoas   3896     Pessoas
# MU    Pessoas  10263    Pessoas  ...  10945     Pessoas  10993     Pessoas
# MU    Pessoas  85414    Pessoas  ...  94263     Pessoas  95018     Pessoas
#
#      2021 Unnamed: 29   2024 Unnamed: 31    2025 Unnamed: 33
# MU  36211     Pessoas  33223     Pessoas   33141     Pessoas
# MU   2452     Pessoas   2355     Pessoas    2355     Pessoas
# MU   3906     Pessoas   3625     Pessoas    3617     Pessoas
# MU  11039     Pessoas  10109     Pessoas   10097     Pessoas
# MU  95752     Pessoas  99678     Pessoas  100071     Pessoas
#
# [5 rows x 34 columns]

# %%
população_rmvp.columns
# Out:
# Index(['Cód.Município', 'Municipio', '2006', 'Unnamed: 3', '2008',
#        'Unnamed: 5', '2009', 'Unnamed: 7', '2011', 'Unnamed: 9', '2012',
#        'Unnamed: 11', '2013', 'Unnamed: 13', '2014', 'Unnamed: 15', '2015',
#        'Unnamed: 17', '2016', 'Unnamed: 19', '2017', 'Unnamed: 21', '2018',
#        'Unnamed: 23', '2019', 'Unnamed: 25', '2020', 'Unnamed: 27', '2021',
#        'Unnamed: 29', '2024', 'Unnamed: 31', '2025', 'Unnamed: 33'],
#       dtype='object')

# %%
população_rmvp.reset_index(drop=True, inplace=True)

# %% [markdown]
# * Visualizando como está o dataframe

# %%
população_rmvp.head(5)
# Out:
#    Cód.Município       Municipio   2006 Unnamed: 3   2008 Unnamed: 5   2009  \
# 0        3502507  Aparecida (SP)  36129    Pessoas  37405    Pessoas  37629
# 1        3503158     Arapeí (SP)   2857    Pessoas   2587    Pessoas   2582
# 2        3503505     Areias (SP)   3834    Pessoas   3684    Pessoas   3690
# 3        3504909    Bananal (SP)  10185    Pessoas  10727    Pessoas  10822
# 4        3508504   Caçapava (SP)  83574    Pessoas  84406    Pessoas  85181
#
#   Unnamed: 7   2011 Unnamed: 9  ...   2019 Unnamed: 25   2020 Unnamed: 27  \
# 0    Pessoas  35015    Pessoas  ...  36157     Pessoas  36185     Pessoas
# 1    Pessoas   2484    Pessoas  ...   2469     Pessoas   2460     Pessoas
# 2    Pessoas   3704    Pessoas  ...   3886     Pessoas   3896     Pessoas
# 3    Pessoas  10263    Pessoas  ...  10945     Pessoas  10993     Pessoas
# 4    Pessoas  85414    Pessoas  ...  94263     Pessoas  95018     Pessoas
#
#     2021 Unnamed: 29   2024 Unnamed: 31    2025 Unnamed: 33
# 0  36211     Pessoas  33223     Pessoas   33141     Pessoas
# 1   2452     Pessoas   2355     Pessoas    2355     Pessoas
# 2   3906     Pessoas   3625     Pessoas    3617     Pessoas
# 3  11039     Pessoas  10109     Pessoas   10097     Pessoas
# 4  95752     Pessoas  99678     Pessoas  100071     Pessoas
#
# [5 rows x 34 columns]

# %% [markdown]
# * Removendo colunas sem utilidade

# %%
população_rmvp.drop(columns=['Unnamed: 3', 'Unnamed: 5','Unnamed: 7','Unnamed: 9','Unnamed: 11','Unnamed: 13',
                             'Unnamed: 15','Unnamed: 17','Unnamed: 19','Unnamed: 21','Unnamed: 23',
                             'Unnamed: 25','Unnamed: 27','Unnamed: 29','Unnamed: 31','Unnamed: 33']
                    ,inplace=True)

# %%
população_rmvp.reset_index(drop=True, inplace=True)

# %% [markdown]
# * Resetado o index e vizualizando como estão os dados

# %%
população_rmvp.head(5)
# Out:
#    Cód.Município       Municipio   2006   2008   2009   2011   2012   2013  \
# 0        3502507  Aparecida (SP)  36129  37405  37629  35015  35023  36151
# 1        3503158     Arapeí (SP)   2857   2587   2582   2484   2475   2541
# 2        3503505     Areias (SP)   3834   3684   3690   3704   3711   3839
# 3        3504909    Bananal (SP)  10185  10727  10822  10263  10301  10680
# 4        3508504   Caçapava (SP)  83574  84406  85181  85414  86054  89668
#
#     2014   2015   2016   2017   2018   2019   2020   2021   2024    2025
# 0  36184  36217  36248  36279  36129  36157  36185  36211  33223   33141
# 1   2532   2524   2516   2509   2478   2469   2460   2452   2355    2355
# 2   3849   3859   3869   3879   3876   3886   3896   3906   3625    3617
# 3  10728  10775  10821  10867  10896  10945  10993  11039  10109   10097
# 4  90426  91162  91883  92587  93488  94263  95018  95752  99678  100071

# %% [markdown]
# * Formatando os nomes da cidades

# %%
população_rmvp.replace(r'(SP)', '', inplace=True, regex=True)

# %%
população_rmvp.replace(r'\(|\)', '', inplace=True, regex=True)

# %%
população_rmvp.head(5)
# Out:
#    Cód.Município   Municipio   2006   2008   2009   2011   2012   2013   2014  \
# 0        3502507  Aparecida   36129  37405  37629  35015  35023  36151  36184
# 1        3503158     Arapeí    2857   2587   2582   2484   2475   2541   2532
# 2        3503505     Areias    3834   3684   3690   3704   3711   3839   3849
# 3        3504909    Bananal   10185  10727  10822  10263  10301  10680  10728
# 4        3508504   Caçapava   83574  84406  85181  85414  86054  89668  90426
#
#     2015   2016   2017   2018   2019   2020   2021   2024    2025
# 0  36217  36248  36279  36129  36157  36185  36211  33223   33141
# 1   2524   2516   2509   2478   2469   2460   2452   2355    2355
# 2   3859   3869   3879   3876   3886   3896   3906   3625    3617
# 3  10775  10821  10867  10896  10945  10993  11039  10109   10097
# 4  91162  91883  92587  93488  94263  95018  95752  99678  100071

# %% [markdown]
# * Deixando o codigo do municipio igual ao que está no Datasus, para ficar igual nas duas.

# %%
população_rmvp['Cód.Município'] = população_rmvp['Cód.Município'].astype(str).str[:-1]
display(população_rmvp.head())
# Out:
#   Cód.Município   Municipio   2006   2008   2009   2011   2012   2013   2014  \
# 0        350250  Aparecida   36129  37405  37629  35015  35023  36151  36184
# 1        350315     Arapeí    2857   2587   2582   2484   2475   2541   2532
# 2        350350     Areias    3834   3684   3690   3704   3711   3839   3849
# 3        350490    Bananal   10185  10727  10822  10263  10301  10680  10728
# 4        350850   Caçapava   83574  84406  85181  85414  86054  89668  90426
#
#     2015   2016   2017   2018   2019   2020   2021   2024    2025
# 0  36217  36248  36279  36129  36157  36185  36211  33223   33141
# 1   2524   2516   2509   2478   2469   2460   2452   2355    2355
# 2   3859   3869   3879   3876   3886   3896   3906   3625    3617
# 3  10775  10821  10867  10896  10945  10993  11039  10109   10097
# 4  91162  91883  92587  93488  94263  95018  95752  99678  100071

# %% [markdown]
# * Como não temos dados de 2007 , subtitui pela média aritmética dos anos de 2006 e 2008.
# * Para os anos de 2022 e 2023 repliquei do ano de 2021.

# %%
população_rmvp['2007'] = (população_rmvp['2006']+população_rmvp['2008'])//2
população_rmvp['2022'] = população_rmvp['2021']
população_rmvp['2023'] = população_rmvp['2021']

# %%
população_rmvp.head(5)
# Out:
#   Cód.Município   Municipio   2006   2008   2009   2011   2012   2013   2014  \
# 0        350250  Aparecida   36129  37405  37629  35015  35023  36151  36184
# 1        350315     Arapeí    2857   2587   2582   2484   2475   2541   2532
# 2        350350     Areias    3834   3684   3690   3704   3711   3839   3849
# 3        350490    Bananal   10185  10727  10822  10263  10301  10680  10728
# 4        350850   Caçapava   83574  84406  85181  85414  86054  89668  90426
#
#     2015  ...   2017   2018   2019   2020   2021   2024    2025   2007   2022  \
# 0  36217  ...  36279  36129  36157  36185  36211  33223   33141  36767  36211
# 1   2524  ...   2509   2478   2469   2460   2452   2355    2355   2722   2452
# 2   3859  ...   3879   3876   3886   3896   3906   3625    3617   3759   3906
# 3  10775  ...  10867  10896  10945  10993  11039  10109   10097  10456  11039
# 4  91162  ...  92587  93488  94263  95018  95752  99678  100071  83990  95752
#
#     2023
# 0  36211
# 1   2452
# 2   3906
# 3  11039
# 4  95752
#
# [5 rows x 21 columns]

# %%
order = ['Cód.Município', 'Municipio', '2006','2007', '2008', '2009', '2011', '2012',
       '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
       '2022', '2023', '2024', '2025']
população_rmvp = população_rmvp[order]

# %% [markdown]
# * Transformando a tabela em dataframe

# %%
população_rmvp = pd.DataFrame(população_rmvp)

# %% [markdown]
# * Verificando os tipos de dados

# %%
população_rmvp.dtypes
# Out:
# Cód.Município    object
# Municipio        object
# 2006              int64
# 2007              int64
# 2008              int64
# 2009              int64
# 2011              int64
# 2012              int64
# 2013              int64
# 2014              int64
# 2015              int64
# 2016              int64
# 2017              int64
# 2018              int64
# 2019              int64
# 2020              int64
# 2021              int64
# 2022              int64
# 2023              int64
# 2024              int64
# 2025              int64
# dtype: object

# %% [markdown]
# # Pronto foi uma organização de dados simples que vou utilizar em outro projeto.

# %%
população_rmvp.to_csv('../data/população_rmvp.csv', index=False)
